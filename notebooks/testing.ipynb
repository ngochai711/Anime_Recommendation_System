# %%
import pandas as pd
HOME_DIRECTORY = '/media/knguyen02311/Data Disk/DataScience/machine_learning/ML_cong_cu/Anime_Recommendation_System/application/backend_flask/'

# %%
anime_table = pd.read_csv(HOME_DIRECTORY + "../../dataset/db_anime.csv")
anime_table = anime_table[anime_table['MAL_ID'] >= 124]

# %%
anime_table
# Out:
#        MAL_ID                             Name  Score  \
# 103       124          Fushigi Yuugi: Eikouden   6.86
# 104       125                          Futakoi   6.49
# 105       126              Futakoi Alternative   6.91
# 106       127                     Gate Keepers   6.96
# 107       128                  Gate Keepers 21   6.79
# ...       ...                              ...    ...
# 17557   48481  Daomu Biji Zhi Qinling Shen Shu    NaN
# 17558   48483                     Mieruko-chan    NaN
# 17559   48488  Higurashi no Naku Koro ni Sotsu    NaN
# 17560   48491      Yama no Susume: Next Summit    NaN
# 17561   48492                    Scarlet Nexus    NaN
#
#                                                   Genres  \
# 103           Adventure, Fantasy, Romance, Drama, Shoujo
# 104                              Comedy, Romance, School
# 105                               Comedy, Drama, Romance
# 106      Action, Sci-Fi, Comedy, Fantasy, Mecha, Shounen
# ...
