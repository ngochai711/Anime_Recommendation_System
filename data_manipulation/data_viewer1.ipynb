# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
data_location = './../dataset/'

df_anime = pd.read_csv(os.path.join(data_location, 'anime.csv'))
df_anime_with_synopsis = pd.read_csv(os.path.join(data_location, 'anime_with_synopsis.csv'))
df_animelist = pd.read_csv(os.path.join(data_location, 'animelist.csv'))
df_rating_complete = pd.read_csv(os.path.join(data_location, 'rating_complete.csv'))
df_watching_status = pd.read_csv(os.path.join(data_location, 'watching_status.csv'))

# %%
df_anime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17562 entries, 0 to 17561
# Data columns (total 35 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MAL_ID         17562 non-null  int64
#  1   Name           17562 non-null  object
#  2   Score          17562 non-null  object
#  3   Genres         17562 non-null  object
#  4   English name   17562 non-null  object
#  5   Japanese name  17562 non-null  object
#  6   Type           17562 non-null  object
#  7   Episodes       17562 non-null  object
#  8   Aired          17562 non-null  object
#  9   Premiered      17562 non-null  object
#  10  Producers      17562 non-null  object
#  11  Licensors      17562 non-null  object
#  12  Studios        17562 non-null  object
#  13  Source         17562 non-null  object
#  14  Duration       17562 non-null  object
#  15  Rating         17562 non-null  object
#  16  Ranked         17562 non-null  object
# ...

# %%
df_anime.loc[0]['Genres'].split(", ")
# Out:
# ['Action', 'Adventure', 'Comedy', 'Drama', 'Sci-Fi', 'Space']

# %%
df_anime.loc[0]
# Out:
# MAL_ID                                                         1
# Name                                                Cowboy Bebop
# Score                                                       8.78
# Genres           Action, Adventure, Comedy, Drama, Sci-Fi, Space
# English name                                        Cowboy Bebop
# Japanese name                                          カウボーイビバップ
# Type                                                          TV
# Episodes                                                      26
# Aired                                Apr 3, 1998 to Apr 24, 1999
# Premiered                                            Spring 1998
# Producers                                          Bandai Visual
# Licensors                       Funimation, Bandai Entertainment
# Studios                                                  Sunrise
# Source                                                  Original
# ...

# %%
df_anime_with_synopsis.loc[0, 'sypnopsis']
# Out:
# 'In the year 2071, humanity has colonized several of the planets and moons of the solar system leaving the now uninhabitable surface of planet Earth behind. The Inter Solar System Police attempts to keep peace in the galaxy, aided in part by outlaw bounty hunters, referred to as "Cowboys." The ragtag team aboard the spaceship Bebop are two such individuals. Mellow and carefree Spike Spiegel is balanced by his boisterous, pragmatic partner Jet Black as the pair makes a living chasing bounties and collecting rewards. Thrown off course by the addition of new members that they meet in their travels—Ein, a genetically engineered, highly intelligent Welsh Corgi; femme fatale Faye Valentine, an enigmatic trickster with memory loss; and the strange computer whiz kid Edward Wong—the crew embarks on thrilling adventures that unravel each member\'s dark and mysterious past little by little. Well-balanced with high density action and light-hearted comedy, Cowboy Bebop is a space Western classic 
# ...

# %%
df_anime.loc[35]
# Out:
# MAL_ID                                                          54
# Name                                             Appleseed (Movie)
# Score                                                          7.1
# Genres           Action, Military, Sci-Fi, Police, Drama, Mecha...
# English name                                               Unknown
# Japanese name                                              アップルシード
# Type                                                         Movie
# Episodes                                                         1
# Aired                                                 Apr 17, 2004
# Premiered                                                  Unknown
# Producers        Mainichi Broadcasting System, Toho, TYO Animat...
# Licensors               Sentai Filmworks, Geneon Entertainment USA
# Studios                                           Digital Frontier
# Source                                                       Manga
# ...

# %%
(df_anime['Name'] == 'Unknown').sum(), df_anime['Rating'].unique()
# Out:
# (0,
#  array(['R - 17+ (violence & profanity)', 'PG-13 - Teens 13 or older',
#         'PG - Children', 'R+ - Mild Nudity', 'G - All Ages', 'Rx - Hentai',
#         'Unknown'], dtype=object))

# %%
df_anime
# Out:
#        MAL_ID                             Name    Score  \
# 0           1                     Cowboy Bebop     8.78
# 1           5  Cowboy Bebop: Tengoku no Tobira     8.39
# 2           6                           Trigun     8.24
# 3           7               Witch Hunter Robin     7.27
# 4           8                   Bouken Ou Beet     6.98
# ...       ...                              ...      ...
# 17557   48481  Daomu Biji Zhi Qinling Shen Shu  Unknown
# 17558   48483                     Mieruko-chan  Unknown
# 17559   48488  Higurashi no Naku Koro ni Sotsu  Unknown
# 17560   48491      Yama no Susume: Next Summit  Unknown
# 17561   48492                    Scarlet Nexus  Unknown
#
#                                                   Genres  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3      Action, Mystery, Police, Supernatural, Drama, ...
# ...

# %%
df_anime_with_synopsis
# Out:
#        MAL_ID                             Name    Score  \
# 0           1                     Cowboy Bebop     8.78
# 1           5  Cowboy Bebop: Tengoku no Tobira     8.39
# 2           6                           Trigun     8.24
# 3           7               Witch Hunter Robin     7.27
# 4           8                   Bouken Ou Beet     6.98
# ...       ...                              ...      ...
# 16209   48481  Daomu Biji Zhi Qinling Shen Shu  Unknown
# 16210   48483                     Mieruko-chan  Unknown
# 16211   48488  Higurashi no Naku Koro ni Sotsu  Unknown
# 16212   48491      Yama no Susume: Next Summit  Unknown
# 16213   48492                    Scarlet Nexus  Unknown
#
#                                                   Genres  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3      Action, Mystery, Police, Supernatural, Drama, ...
# ...

# %%
df_anime.loc[:, ['MAL_ID', 'Type', 'Episode']]
# Out:
#         Type
# 0         TV
# 1      Movie
# 2         TV
# 3         TV
# 4         TV
# ...      ...
# 17557    ONA
# 17558     TV
# 17559     TV
# 17560     TV
# 17561     TV
#
# [17562 rows x 1 columns]

# %%
df_anime_with_synopsis.set_index('MAL_ID').join(df_anime.set_index('MAL_ID').drop(['']))
# Out:
#                                  Name_a  Score_a  \
# MAL_ID
# 1                          Cowboy Bebop     8.78
# 5       Cowboy Bebop: Tengoku no Tobira     8.39
# 6                                Trigun     8.24
# 7                    Witch Hunter Robin     7.27
# 8                        Bouken Ou Beet     6.98
# ...                                 ...      ...
# 48481   Daomu Biji Zhi Qinling Shen Shu  Unknown
# 48483                      Mieruko-chan  Unknown
# 48488   Higurashi no Naku Koro ni Sotsu  Unknown
# 48491       Yama no Susume: Next Summit  Unknown
# 48492                     Scarlet Nexus  Unknown
#
#                                                  Genres_a  \
# MAL_ID
# 1         Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 5                   Action, Drama, Mystery, Sci-Fi, Space
# 6       Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 7       Action, Mystery, Police, Supernatural, Drama, ...
# 8               Adventure, Fantasy, Shounen, Supernatural
# ...

# %%
df_anime.set_index('MAL_ID') \
   .join(df_anime_with_synopsis.set_index('MAL_ID').drop(['Name', 'Genres', 'Score'], axis=1)) \
   .drop(['Score-10', 'Score-9', 'Score-8', 'Score-7', 'Score-6', 'Score-5', 'Score-4', 'Score-3', 'Score-2', 'Score-1', 'Members', 'Favorites', 'Watching', 'Completed',
         'On-Hold', 'Dropped', 'Plan to Watch', 'Ranked', 'Popularity'], axis=1)
# Out:
#                                    Name    Score  \
# MAL_ID
# 1                          Cowboy Bebop     8.78
# 5       Cowboy Bebop: Tengoku no Tobira     8.39
# 6                                Trigun     8.24
# 7                    Witch Hunter Robin     7.27
# 8                        Bouken Ou Beet     6.98
# ...                                 ...      ...
# 48481   Daomu Biji Zhi Qinling Shen Shu  Unknown
# 48483                      Mieruko-chan  Unknown
# 48488   Higurashi no Naku Koro ni Sotsu  Unknown
# 48491       Yama no Susume: Next Summit  Unknown
# 48492                     Scarlet Nexus  Unknown
#
#                                                    Genres  \
# MAL_ID
# 1         Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 5                   Action, Drama, Mystery, Sci-Fi, Space
# 6       Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 7       Action, Mystery, Police, Supernatural, Drama, ...
# 8               Adventure, Fantasy, Shounen, Supernatural
# ...

# %%
df_animelist
# Out:
#            user_id  anime_id  rating  watching_status  watched_episodes
# 0                0        67       9                1                 1
# 1                0      6702       7                1                 4
# 2                0       242      10                1                 4
# 3                0      4898       0                1                 1
# 4                0        21      10                1                 0
# ...            ...       ...     ...              ...               ...
# 109224742   353404       507       7                2                 2
# 109224743   353404       392       9                2               112
# 109224744   353404       882       6                2                 1
# 109224745   353404       883       8                2                 1
# 109224746   353404       149       0                6                 0
#
# [109224747 rows x 5 columns]

# %%
df_animelist[df_animelist['user_id'] == 48304].loc[:, 'anime_id'].duplicated().sum()
# Out:
# 0

# %%
df_rating_complete
# Out:
#           user_id  anime_id  rating
# 0               0       430       9
# 1               0      1004       5
# 2               0      3010       7
# 3               0       570       7
# 4               0      2762       9
# ...           ...       ...     ...
# 57633273   353404       502       8
# 57633274   353404       987       4
# 57633275   353404       225       8
# 57633276   353404       243       7
# 57633277   353404       896       7
#
# [57633278 rows x 3 columns]

# %%
df_watching_status
# Out:
#    status         description
# 0       1  Currently Watching
# 1       2           Completed
# 2       3             On Hold
# 3       4             Dropped
# 4       6       Plan to Watch
